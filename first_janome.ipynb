# %%
from janome.tokenizer import Tokenizer

# %%
t=Tokenizer()

# %%
malist = t.tokenize("Python（パイソン）は、汎用のプログラミング言語である。コードがシンプルで扱いやすく設計されており、C言語などに比べて、さまざまなプログラムを分かりやすく、少ないコード行数で書けるといった特徴がある")

# %%
for n in malist:
    print(n)
# Out:
# Python	名詞,一般,*,*,*,*,Python,*,*
# （	記号,括弧開,*,*,*,*,（,（,（
# パイソン	名詞,固有名詞,一般,*,*,*,パイソン,*,*
# ）	記号,括弧閉,*,*,*,*,）,）,）
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# 汎用	名詞,一般,*,*,*,*,汎用,ハンヨウ,ハンヨー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# プログラミング	名詞,サ変接続,*,*,*,*,プログラミング,プログラミング,プログラミング
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# ある	助動詞,*,*,*,五段・ラ行アル,基本形,ある,アル,アル
# 。	記号,句点,*,*,*,*,。,。,。
# コード	名詞,一般,*,*,*,*,コード,コード,コード
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# シンプル	名詞,形容動詞語幹,*,*,*,*,シンプル,シンプル,シンプル
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 扱い	動詞,自立,*,*,五段・ワ行促音便,連用形,扱う,アツカイ,アツカイ
# やすく	形容詞,非自立,*,*,形容詞・アウオ段,連用テ接続,やすい,ヤスク,ヤスク
# 設計	名詞,サ変接続,*,*,*,*,設計,セッケイ,セッケイ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# おり	動詞,非自立,*,*,五段・ラ行,連用形,おる,オリ,オリ
# 、	記号,読点,*,*,*,*,、,、,、
# C	名詞,固有名詞,組織,*,*,*,C,*,*
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# など	助詞,副助詞,*,*,*,*,など,ナド,ナド
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 比べ	動詞,自立,*,*,一段,連用形,比べる,クラベ,クラベ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 、	記号,読点,*,*,*,*,、,、,、
# ...
